# %% [markdown]
# #  Teoria Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# * Para cambiar la ruta
#
# import os
#
# dir = os.getcwd()
#
# os.chdir("rutaNueva")

# %% [markdown]
# * Lectura de datos
#  * Seleccionar columnas especificas ( DataFrames y Series)
#  * Funciones de columas
#  * Creacion de clumnas
#  * Seleccion de filas por filtraje
#  * iloc, loc
#  * Cambiar nombres de columas
#  * Resetear indice
#  * Eliminar filas / columnas
#  * Crear DataFrame

# %% [markdown]
# # Seleccionar columnas especificas ( DataFrames y Series)

# %%
iris = pd.read_excel("iris.xlsx")
# funciona commo java io, rutas y demas para enlazar
# esto son dataframes 
iris
# Out:
#      Largo Sepalo   Ancho Sepalo   Largo Petalo   Ancho Petalo           Clase
# 0             5.1            3.5            1.4            0.2     Iris-setosa
# 1             4.9            3.0            1.4            0.2     Iris-setosa
# 2             4.7            3.2            1.3            0.2     Iris-setosa
# 3             4.6            3.1            1.5            0.2     Iris-setosa
# 4             5.0            3.6            1.4            0.2     Iris-setosa
# ..            ...            ...            ...            ...             ...
# 145           6.7            3.0            5.2            2.3  Iris-virginica
# 146           6.3            2.5            5.0            1.9  Iris-virginica
# 147           6.5            3.0            5.2            2.0  Iris-virginica
# 148           6.2            3.4            5.4            2.3  Iris-virginica
# 149           5.9            3.0            5.1            1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris[["Largo Sepalo", " Ancho Sepalo"]]
# se pone tal cula con espacios y eso, cuidado
# Out:
#      Largo Sepalo   Ancho Sepalo
# 0             5.1            3.5
# 1             4.9            3.0
# 2             4.7            3.2
# 3             4.6            3.1
# 4             5.0            3.6
# ..            ...            ...
# 145           6.7            3.0
# 146           6.3            2.5
# 147           6.5            3.0
# 148           6.2            3.4
# 149           5.9            3.0
#
# [150 rows x 2 columns]

# %%
print(iris.columns)
# podemos verificar los nombres de las colums
# Out:
# Index(['Largo Sepalo', ' Ancho Sepalo', ' Largo Petalo', ' Ancho Petalo',
#        ' Clase'],
#       dtype='object')

# %%
df = pd.read_excel("iris.xlsx", sheet_name=0)
df.head() # primeras filas
# Out:
#    Largo Sepalo   Ancho Sepalo   Largo Petalo   Ancho Petalo        Clase
# 0           5.1            3.5            1.4            0.2  Iris-setosa
# 1           4.9            3.0            1.4            0.2  Iris-setosa
# 2           4.7            3.2            1.3            0.2  Iris-setosa
# 3           4.6            3.1            1.5            0.2  Iris-setosa
# 4           5.0            3.6            1.4            0.2  Iris-setosa

# %%
df.tail(5) # ultimas filas
# Out:
#      Largo Sepalo   Ancho Sepalo   Largo Petalo   Ancho Petalo           Clase
# 145           6.7            3.0            5.2            2.3  Iris-virginica
# 146           6.3            2.5            5.0            1.9  Iris-virginica
# 147           6.5            3.0            5.2            2.0  Iris-virginica
# 148           6.2            3.4            5.4            2.3  Iris-virginica
# 149           5.9            3.0            5.1            1.8  Iris-virginica

# %%
df.shape # atributo tamaño dataframe
# Out:
# (150, 5)

# %%
len(df)
# Out:
# 150

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.describe()
# Out:
#        Largo Sepalo   Ancho Sepalo   Largo Petalo   Ancho Petalo
# count    150.000000     150.000000     150.000000     150.000000
# mean       5.843333       3.054000       3.758667       1.198667
# std        0.828066       0.433594       1.764420       0.763161
# min        4.300000       2.000000       1.000000       0.100000
# 25%        5.100000       2.800000       1.600000       0.300000
# 50%        5.800000       3.000000       4.350000       1.300000
# 75%        6.400000       3.300000       5.100000       1.800000
# max        7.900000       4.400000       6.900000       2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Largo Sepalo   150 non-null    float64
#  1    Ancho Sepalo  150 non-null    float64
#  2    Largo Petalo  150 non-null    float64
#  3    Ancho Petalo  150 non-null    float64
#  4    Clase         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.sum()
#sumas de cada colum, suma todo lo que no se none, para saber si esta vacio
# Out:
# Largo Sepalo                                                 876.5
#  Ancho Sepalo                                                458.1
#  Largo Petalo                                                563.8
#  Ancho Petalo                                                179.8
#  Clase           Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# dtype: object

# %%
df[["Largo Sepalo", " Ancho Sepalo"]].sum()
# busca esa colums y hace sum de estas
# Out:
# Largo Sepalo     876.5
#  Ancho Sepalo    458.1
# dtype: float64

# %%
df2 = pd.read_csv("iris.csv")
df2
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
print(type(df2[["Largo Sepalo"]]))
# esto es un dataFrame reducido a eso (indices y colums)

print(type(df2["Largo Sepalo"]))
# esto es una serie (valores ordenados)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
df2.Clase
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Clase, Length: 150, dtype: object

# %% [markdown]
# # Funciones de columnas

# %%
#value counts
df2[["Largo Sepalo", "Ancho Sepalo"]].value_counts()
#excel espacio, csv sin espacio
# Out:
# Largo Sepalo  Ancho Sepalo
# 5.8           2.7             4
# 6.5           3.0             3
# 6.7           3.1             3
# 6.9           3.1             3
# 4.9           3.1             3
#                              ..
# 5.5           2.3             1
# 5.4           3.7             1
#               3.0             1
# 5.3           3.7             1
# 7.9           3.8             1
# Name: count, Length: 116, dtype: int64

# %%
df2.columns
# Out:
# Index(['Largo Sepalo', 'Ancho Sepalo', 'Largo Petalo', 'Ancho Petalo',
#        'Clase'],
#       dtype='object')

# %%
print(df2[["Largo Sepalo"]].min())
print(df2[["Largo Sepalo"]].sum())
print(df2[["Largo Sepalo"]].max())
print(df2[["Largo Sepalo"]].median())
# Out:
# Largo Sepalo    4.3
# dtype: float64
# Largo Sepalo    876.5
# dtype: float64
# Largo Sepalo    7.9
# dtype: float64
# Largo Sepalo    5.8
# dtype: float64

# %%
print(df2[["Largo Sepalo"]].quantile(0.1))
# Out:
# Largo Sepalo    4.8
# Name: 0.1, dtype: float64

# %%
df2["Clase"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# # Creacion de columnas

# %%
df2["ejemplo"]=2
df2
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase  \
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
#      ejemplo
# 0          2
# 1          2
# ...

# %%
df2["Largo Sepalo"].cumsum()
# Out:
# 0        5.1
# 1       10.0
# 2       14.7
# 3       19.3
# 4       24.3
#        ...
# 145    851.6
# 146    857.9
# 147    864.4
# 148    870.6
# 149    876.5
# Name: Largo Sepalo, Length: 150, dtype: float64

# %%
df2[" Suma Acumular LargoSepalo "] = df2["Largo Sepalo"].cumsum()
df2
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase  \
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
#      ejemplo   Suma Acumular LargoSepalo
# ...

# %%
df2.head()
# Out:
#    Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo        Clase  \
# 0           5.1           3.5           1.4           0.2  Iris-setosa
# 1           4.9           3.0           1.4           0.2  Iris-setosa
# 2           4.7           3.2           1.3           0.2  Iris-setosa
# 3           4.6           3.1           1.5           0.2  Iris-setosa
# 4           5.0           3.6           1.4           0.2  Iris-setosa
#
#    ejemplo   Suma Acumular LargoSepalo
# 0        2                          5.1
# 1        2                         10.0
# 2        2                         14.7
# 3        2                         19.3
# 4        2                         24.3

# %%
del df2[" Suma Acumular LargoSepalo "]

# %%
df2
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase  \
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
#      ejemplo
# 0          2
# 1          2
# ...

# %%
df2["KPI 27"] = df2["Largo Sepalo"]**2 - df2["Largo Sepalo"]

# %%
df2
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
del df2["ejemplo"]

# %% [markdown]
# # Seleccion de filas por filtraje

# %%
df2[["Largo Sepalo"]]>5
# Out:
#      Largo Sepalo
# 0            True
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 145          True
# 146          True
# 147          True
# 148          True
# 149          True
#
# [150 rows x 1 columns]

# %%
df2[df2["Largo Sepalo"]>5]

df2[df2["Clase"]=="Iris-virginica"].head()
df2[df2.Clase=="Iris-virginica"].head()
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 100           6.3           3.3           6.0           2.5  Iris-virginica
# 101           5.8           2.7           5.1           1.9  Iris-virginica
# 102           7.1           3.0           5.9           2.1  Iris-virginica
# 103           6.3           2.9           5.6           1.8  Iris-virginica
# 104           6.5           3.0           5.8           2.2  Iris-virginica

# %%
df2[
    (df2["Largo Sepalo"]>5)
      & (df2["Largo Sepalo"]<7 )
    ]
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 5             5.4           3.9           1.7           0.4     Iris-setosa
# 10            5.4           3.7           1.5           0.2     Iris-setosa
# 14            5.8           4.0           1.2           0.2     Iris-setosa
# 15            5.7           4.4           1.5           0.4     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
# [105 rows x 5 columns]

# %%
# ancho del sepalo = 3.5 y mostrar largo petalo y clase
columnas=["Largo Petalo", "Clase"]
df2[df2["Ancho Sepalo"]==3.5][columnas]
# Out:
#     Largo Petalo        Clase
# 0            1.4  Iris-setosa
# 17           1.4  Iris-setosa
# 27           1.5  Iris-setosa
# 36           1.3  Iris-setosa
# 40           1.3  Iris-setosa
# 43           1.6  Iris-setosa

# %%
df2[df2["Ancho Sepalo"]==3.5][["Largo Petalo", "Clase"]]
# habria que poner el doble corchete
# Out:
#     Largo Petalo        Clase
# 0            1.4  Iris-setosa
# 17           1.4  Iris-setosa
# 27           1.5  Iris-setosa
# 36           1.3  Iris-setosa
# 40           1.3  Iris-setosa
# 43           1.6  Iris-setosa

# %% [markdown]
# * calcular el promedio de "largo sepalo" para la clase iris-sectosa.

# %%
df[df2.Clase=="Iris-setosa"][["Largo Sepalo"]].mean()
df[df2.Clase=="Iris-setosa"]["Largo Sepalo"].mean()
# Out:
# 5.006

# %%
df[df2.Clase=="Iris-setosa"]["Largo Sepalo"].mean()
df[df2.Clase=="Iris-versicolor"]["Largo Sepalo"].mean()
df[df2.Clase=="Iris-virginica"]["Largo Sepalo"].mean()

for i in df2.Clase.unique():
    j = df[df2.Clase==i]["Largo Sepalo"].mean()
    print(f"Media de {i}  = { j }")
# Out:
# Media de Iris-setosa  = 5.006
# Media de Iris-versicolor  = 5.936
# Media de Iris-virginica  = 6.587999999999998

# %% [markdown]
# # iloc, loc (seleccionamos filas y columnas, y podemos modifciarlas)

# %%
csv = df2.copy()
exc = df.copy()
csv
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# * iloc

# %%
csv.iloc[1,1]
# Out:
# 3.0

# %%
csv.iloc[1,1] = 100 #asi si funciona
#csv.iloc[1][1] = 100 # asi no fucnuina
csv.head()
# Out:
#    Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo        Clase
# 0           5.1           3.5           1.4           0.2  Iris-setosa
# 1           4.9         100.0           1.4           0.2  Iris-setosa
# 2           4.7           3.2           1.3           0.2  Iris-setosa
# 3           4.6           3.1           1.5           0.2  Iris-setosa
# 4           5.0           3.6           1.4           0.2  Iris-setosa

# %%
# seleciona filas de 50 a 60 y columnas largo petalo y ancho petalo
csv.iloc[50:61, 2:4]
# Out:
#     Largo Petalo  Ancho Petalo
# 50           4.7           1.4
# 51           4.5           1.5
# 52           4.9           1.5
# 53           4.0           1.3
# 54           4.6           1.5
# 55           4.5           1.3
# 56           4.7           1.6
# 57           3.3           1.0
# 58           4.6           1.3
# 59           3.9           1.4
# 60           3.5           1.0

# %% [markdown]
# * loc

# %%
csv.index = ["ind " + str(i) for i in range(150)]
csv
# Out:
#          Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo  \
# ind 0             5.1           3.5           1.4           0.2
# ind 1             4.9         100.0           1.4           0.2
# ind 2             4.7           3.2           1.3           0.2
# ind 3             4.6           3.1           1.5           0.2
# ind 4             5.0           3.6           1.4           0.2
# ...               ...           ...           ...           ...
# ind 145           6.7           3.0           5.2           2.3
# ind 146           6.3           2.5           5.0           1.9
# ind 147           6.5           3.0           5.2           2.0
# ind 148           6.2           3.4           5.4           2.3
# ind 149           5.9           3.0           5.1           1.8
#
#                   Clase
# ind 0       Iris-setosa
# ind 1       Iris-setosa
# ind 2       Iris-setosa
# ind 3       Iris-setosa
# ind 4       Iris-setosa
# ...                 ...
# ...

# %%
csv.loc["ind 2","Largo Sepalo"]
# Out:
# 4.7

# %%
csv.loc[csv["Largo Sepalo"]>=5, "Largo Sepalo"] = 5.5
csv
# Out:
#          Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo  \
# ind 0             5.5           3.5           1.4           0.2
# ind 1             4.9         100.0           1.4           0.2
# ind 2             4.7           3.2           1.3           0.2
# ind 3             4.6           3.1           1.5           0.2
# ind 4             5.5           3.6           1.4           0.2
# ...               ...           ...           ...           ...
# ind 145           5.5           3.0           5.2           2.3
# ind 146           5.5           2.5           5.0           1.9
# ind 147           5.5           3.0           5.2           2.0
# ind 148           5.5           3.4           5.4           2.3
# ind 149           5.5           3.0           5.1           1.8
#
#                   Clase
# ind 0       Iris-setosa
# ind 1       Iris-setosa
# ind 2       Iris-setosa
# ind 3       Iris-setosa
# ind 4       Iris-setosa
# ...                 ...
# ...

# %%
csv.loc[csv["Largo Sepalo"]>=5, "Largo Sepalo"] = "ejm"
csv
# Out:
# C:\Users\garch\AppData\Local\Temp\ipykernel_23008\511479241.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'ejm' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   csv.loc[csv["Largo Sepalo"]>=5, "Largo Sepalo"] = "ejm"
#         Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# ind 0            ejm           3.5           1.4           0.2     Iris-setosa
# ind 1            4.9         100.0           1.4           0.2     Iris-setosa
# ind 2            4.7           3.2           1.3           0.2     Iris-setosa
# ind 3            4.6           3.1           1.5           0.2     Iris-setosa
# ind 4            ejm           3.6           1.4           0.2     Iris-setosa
# ...              ...           ...           ...           ...             ...
# ind 145          ejm           3.0           5.2           2.3  Iris-virginica
# ...

# %%
csv = df2.copy()
csv
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
csv.columns
# Out:
# Index(['Largo Sepalo', 'Ancho Sepalo', 'Largo Petalo', 'Ancho Petalo',
#        'Clase'],
#       dtype='object')

# %%
csv.columns = ["Lsepalo", "Asepalo", "Lpetalo", "Apetalo", "Especie" ]
csv.head()
# Out:
#    Lsepalo  Asepalo  Lpetalo  Apetalo      Especie
# 0      5.1      3.5      1.4      0.2  Iris-setosa
# 1      4.9      3.0      1.4      0.2  Iris-setosa
# 2      4.7      3.2      1.3      0.2  Iris-setosa
# 3      4.6      3.1      1.5      0.2  Iris-setosa
# 4      5.0      3.6      1.4      0.2  Iris-setosa

# %%
csv = csv.rename(columns={"Lsepalo":"LSepalo", "Lpetalo":"LPetalo"})
csv = csv.rename(columns={"Asepalo":"ASepalo", "Apetalo":"APetalo"})
csv
# Out:
#      LSepalo  ASepalo  LPetalo  APetalo         Especie
# 0        5.1      3.5      1.4      0.2     Iris-setosa
# 1        4.9      3.0      1.4      0.2     Iris-setosa
# 2        4.7      3.2      1.3      0.2     Iris-setosa
# 3        4.6      3.1      1.5      0.2     Iris-setosa
# 4        5.0      3.6      1.4      0.2     Iris-setosa
# ..       ...      ...      ...      ...             ...
# 145      6.7      3.0      5.2      2.3  Iris-virginica
# 146      6.3      2.5      5.0      1.9  Iris-virginica
# 147      6.5      3.0      5.2      2.0  Iris-virginica
# 148      6.2      3.4      5.4      2.3  Iris-virginica
# 149      5.9      3.0      5.1      1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
csv.rename(columns={"Especie":"Denominación"}, inplace = True)
# reemplaaz el original sin tener que sobreescribir
csv.head()
# Out:
#    LSepalo  ASepalo  LPetalo  APetalo Denominación
# 0      5.1      3.5      1.4      0.2  Iris-setosa
# 1      4.9      3.0      1.4      0.2  Iris-setosa
# 2      4.7      3.2      1.3      0.2  Iris-setosa
# 3      4.6      3.1      1.5      0.2  Iris-setosa
# 4      5.0      3.6      1.4      0.2  Iris-setosa

# %%
csv = csv.sort_values("Denominación", ascending=False)
# no sobreeescribe
# como se ve el indice no se ha reajustado habra que resetearlo
csv
# Out:
#      LSepalo  ASepalo  LPetalo  APetalo    Denominación
# 149      5.9      3.0      5.1      1.8  Iris-virginica
# 141      6.9      3.1      5.1      2.3  Iris-virginica
# 137      6.4      3.1      5.5      1.8  Iris-virginica
# 125      7.2      3.2      6.0      1.8  Iris-virginica
# 147      6.5      3.0      5.2      2.0  Iris-virginica
# ..       ...      ...      ...      ...             ...
# 4        5.0      3.6      1.4      0.2     Iris-setosa
# 3        4.6      3.1      1.5      0.2     Iris-setosa
# 2        4.7      3.2      1.3      0.2     Iris-setosa
# 1        4.9      3.0      1.4      0.2     Iris-setosa
# 0        5.1      3.5      1.4      0.2     Iris-setosa
#
# [150 rows x 5 columns]

# %% [markdown]
# # Resetear el inidice

# %%
csv = csv.reset_index(drop=True)
csv
# Out:
#      level_0  index  LSepalo  ASepalo  LPetalo  APetalo    Denominación
# 0          0    149      5.9      3.0      5.1      1.8  Iris-virginica
# 1          1    141      6.9      3.1      5.1      2.3  Iris-virginica
# 2          2    137      6.4      3.1      5.5      1.8  Iris-virginica
# 3          3    125      7.2      3.2      6.0      1.8  Iris-virginica
# 4          4    147      6.5      3.0      5.2      2.0  Iris-virginica
# ..       ...    ...      ...      ...      ...      ...             ...
# 145      145      4      5.0      3.6      1.4      0.2     Iris-setosa
# 146      146      3      4.6      3.1      1.5      0.2     Iris-setosa
# 147      147      2      4.7      3.2      1.3      0.2     Iris-setosa
# 148      148      1      4.9      3.0      1.4      0.2     Iris-setosa
# 149      149      0      5.1      3.5      1.4      0.2     Iris-setosa
#
# [150 rows x 7 columns]

# %% [markdown]
# # Eliminar filas/columnas (drop)

# %%
csv.drop([2,5,1], axis = 0)
# elimina 2, 5 y 1; en el eje 0 = filas
# Out:
#      level_0  index  LSepalo  ASepalo  LPetalo  APetalo    Denominación
# 0          0    149      5.9      3.0      5.1      1.8  Iris-virginica
# 3          3    125      7.2      3.2      6.0      1.8  Iris-virginica
# 4          4    147      6.5      3.0      5.2      2.0  Iris-virginica
# 6          6    145      6.7      3.0      5.2      2.3  Iris-virginica
# 7          7    144      6.7      3.3      5.7      2.5  Iris-virginica
# ..       ...    ...      ...      ...      ...      ...             ...
# 145      145      4      5.0      3.6      1.4      0.2     Iris-setosa
# 146      146      3      4.6      3.1      1.5      0.2     Iris-setosa
# 147      147      2      4.7      3.2      1.3      0.2     Iris-setosa
# 148      148      1      4.9      3.0      1.4      0.2     Iris-setosa
# 149      149      0      5.1      3.5      1.4      0.2     Iris-setosa
#
# [147 rows x 7 columns]

# %%
csv.drop(columns={"level_0"})
# Out:
#      index  LSepalo  ASepalo  LPetalo  APetalo    Denominación
# 0      149      5.9      3.0      5.1      1.8  Iris-virginica
# 1      141      6.9      3.1      5.1      2.3  Iris-virginica
# 2      137      6.4      3.1      5.5      1.8  Iris-virginica
# 3      125      7.2      3.2      6.0      1.8  Iris-virginica
# 4      147      6.5      3.0      5.2      2.0  Iris-virginica
# ..     ...      ...      ...      ...      ...             ...
# 145      4      5.0      3.6      1.4      0.2     Iris-setosa
# 146      3      4.6      3.1      1.5      0.2     Iris-setosa
# 147      2      4.7      3.2      1.3      0.2     Iris-setosa
# 148      1      4.9      3.0      1.4      0.2     Iris-setosa
# 149      0      5.1      3.5      1.4      0.2     Iris-setosa
#
# [150 rows x 6 columns]
