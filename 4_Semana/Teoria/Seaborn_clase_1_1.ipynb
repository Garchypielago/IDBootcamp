# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("iris")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.rename({"sepal_length": "LSepal",
            "sepal_width": "ASepal",
            "petal_length": "LPetal",
            "petal_width": "APetal"},
            axis=1, inplace=True
        )
df.head()
# Out:
#    LSepal  ASepal  LPetal  APetal species
# 0     5.1     3.5     1.4     0.2  setosa
# 1     4.9     3.0     1.4     0.2  setosa
# 2     4.7     3.2     1.3     0.2  setosa
# 3     4.6     3.1     1.5     0.2  setosa
# 4     5.0     3.6     1.4     0.2  setosa

# %% [markdown]
# # Exploración inicial del dataframe:
# * -Dimensiones
# * -Nulos -> si hay, preprocesamiento
# * -Asimetria/Curtosis
# * -Info

# %%
df.describe()
# Out:
#            LSepal      ASepal      LPetal      APetal
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.057333    3.758000    1.199333
# std      0.828066    0.435866    1.765298    0.762238
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
sns.pairplot(df)
plt.show()
# Out:
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
df.shape
# Out:
# (150, 5)

# %%
df["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df.isnull()
# Out:
#      LSepal  ASepal  LPetal  APetal  species
# 0     False   False   False   False    False
# 1     False   False   False   False    False
# 2     False   False   False   False    False
# 3     False   False   False   False    False
# 4     False   False   False   False    False
# ..      ...     ...     ...     ...      ...
# 145   False   False   False   False    False
# 146   False   False   False   False    False
# 147   False   False   False   False    False
# 148   False   False   False   False    False
# 149   False   False   False   False    False
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   LSepal   150 non-null    float64
#  1   ASepal   150 non-null    float64
#  2   LPetal   150 non-null    float64
#  3   APetal   150 non-null    float64
#  4   species  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# # Generamos sub-dataframes (para cada especie)

# %%
filtro1 = (df["species"]=="setosa")
df_setosa = df.loc[filtro1]
df_setosa.head()
# Out:
#    LSepal  ASepal  LPetal  APetal species
# 0     5.1     3.5     1.4     0.2  setosa
# 1     4.9     3.0     1.4     0.2  setosa
# 2     4.7     3.2     1.3     0.2  setosa
# 3     4.6     3.1     1.5     0.2  setosa
# 4     5.0     3.6     1.4     0.2  setosa

# %%
filtro2 = (df["species"]=="versicolor")
df_versicolor = df.loc[filtro2]
df_versicolor.head()
# Out:
#     LSepal  ASepal  LPetal  APetal     species
# 50     7.0     3.2     4.7     1.4  versicolor
# 51     6.4     3.2     4.5     1.5  versicolor
# 52     6.9     3.1     4.9     1.5  versicolor
# 53     5.5     2.3     4.0     1.3  versicolor
# 54     6.5     2.8     4.6     1.5  versicolor

# %%
filtro3 = (df["species"]=="virginica")
df_virginica = df.loc[filtro3]
df_virginica.head()
# Out:
#      LSepal  ASepal  LPetal  APetal    species
# 100     6.3     3.3     6.0     2.5  virginica
# 101     5.8     2.7     5.1     1.9  virginica
# 102     7.1     3.0     5.9     2.1  virginica
# 103     6.3     2.9     5.6     1.8  virginica
# 104     6.5     3.0     5.8     2.2  virginica

# %% [markdown]
# # Análisis Univariado
# * Estadística
# * Varibles: Histogrma, Bosplot, Curva Densidad..
#   * Por cada columna (longuitudes y anchuras de Sepalo y Petalo)

# %%
df.describe()
# Out:
#            LSepal      ASepal      LPetal      APetal
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.057333    3.758000    1.199333
# std      0.828066    0.435866    1.765298    0.762238
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %% [markdown]
# ## 1.Longitud sepalo

# %%
# var = "LSepal"
# var_label = "Longitud sepalo"

# # creo sbgrafo con seaborn
# fig, ax = plt.subplots(1,3, figsize=(15,3))

# # Boxplot
# sns.boxplot(data=df[var], ax=ax[0], orient="h", width=0.4)
# ax[0].set_xlabel(var_label)
# ax[0].set_title("Boxplot de " + var_label)

# # Histograma
# sns.histplot(data=df[var], ax=ax[1])
# ax[0].set_xlabel(var_label)
# ax[0].set_ylabel("Frecuencia")
# ax[0].set_title("Histograma de " + var_label)

# # Curva densida
# sns.kdeplot(data=df[var], ax=ax[2], fill=True)
# ax[0].set_xlabel(var_label)
# ax[0].set_ylabel("Densidad")
# ax[0].set_title("Densidad de " + var_label)


# plt.show()

# %%
var = "LSepal"
var_titulo = "Longitud del sépalo"
#creo subgráficos con seaborn
fig, ax = plt.subplots (1,3, figsize=(15,3))
#Boxplot
sns.boxplot(data=df[var], ax=ax[0], orient="h", width=0.4)
ax[0].set_xlabel(var_titulo)
ax[0].set_title("Boxplot de " + var_titulo)
#Histograma
sns.histplot(data=df[var], ax=ax[1])
ax[1].set_xlabel(var_titulo)
ax[1].set_ylabel("Frecuencia")
ax[1].set_title("Histograma de " + var_titulo)

#Curva de Densidad
sns.kdeplot(data=df[var], ax=ax[2], fill=True)
ax[2].set_xlabel(var_titulo)
ax[2].set_ylabel("Densidad")
ax[2].set_title("Densidad de " + var_titulo)
plt.show()
# Out:
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## 2.Anchura sepalo

# %%
var = "ASepal"
var_titulo = "Ancho del sépalo"
#creo subgráficos con seaborn
fig, ax = plt.subplots (1,3, figsize=(15,3))
#Boxplot
sns.boxplot(data=df[var], ax=ax[0], orient="h", width=0.4)
ax[0].set_xlabel(var_titulo)
ax[0].set_title("Boxplot de " + var_titulo)
#Histograma
sns.histplot(data=df[var], ax=ax[1])
ax[1].set_xlabel(var_titulo)
ax[1].set_ylabel("Frecuencia")
ax[1].set_title("Histograma de " + var_titulo)

#Curva de Densidad
sns.kdeplot(data=df[var], ax=ax[2], fill=True)
ax[2].set_xlabel(var_titulo)
ax[2].set_ylabel("Densidad")
ax[2].set_title("Densidad de " + var_titulo)
plt.show()
# Out:
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## 3.Longitud petalo

# %%
var = "LPetal"
var_titulo = "Longitud del petalo"
#creo subgráficos con seaborn
fig, ax = plt.subplots (1,3, figsize=(15,3))
#Boxplot
sns.boxplot(data=df[var], ax=ax[0], orient="h", width=0.4)
ax[0].set_xlabel(var_titulo)
ax[0].set_title("Boxplot de " + var_titulo)
#Histograma
sns.histplot(data=df[var], ax=ax[1])
ax[1].set_xlabel(var_titulo)
ax[1].set_ylabel("Frecuencia")
ax[1].set_title("Histograma de " + var_titulo)

#Curva de Densidad
sns.kdeplot(data=df[var], ax=ax[2], fill=True)
ax[2].set_xlabel(var_titulo)
ax[2].set_ylabel("Densidad")
ax[2].set_title("Densidad de " + var_titulo)
plt.show()
# Out:
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## 4.Anchura petalo

# %%
var = "APetal"
var_titulo = "Ancho del petalo"
#creo subgráficos con seaborn
fig, ax = plt.subplots (1,3, figsize=(15,3))
#Boxplot
sns.boxplot(data=df[var], ax=ax[0], orient="h", width=0.4)
ax[0].set_xlabel(var_titulo)
ax[0].set_title("Boxplot de " + var_titulo)
#Histograma
sns.histplot(data=df[var], ax=ax[1])
ax[1].set_xlabel(var_titulo)
ax[1].set_ylabel("Frecuencia")
ax[1].set_title("Histograma de " + var_titulo)

#Curva de Densidad
sns.kdeplot(data=df[var], ax=ax[2], fill=True)
ax[2].set_xlabel(var_titulo)
ax[2].set_ylabel("Densidad")
ax[2].set_title("Densidad de " + var_titulo)
plt.show()
# Out:
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Análisi Multivariado
# * 1 vs (species) | 2 vs (species) | 3 vs (species)...
#   * Histograma por especie
#   * Curva de densidad por especie
#   * Boxplot/Violin por especie
# * 1vs2
#   * Scatter
#   * Joinplot
# * 3vs4
#   * Scatter
#   * Joinplo
# * Todas las variables vs species
# * Corelacion entre variables

# %% [markdown]
# ## 1.Longitud Sepalo

# %%
var = "LSepal"
var_titulo = "Longitud del sépalo"
#creo subgráficos con seaborn
fig, ax = plt.subplots (1,3, figsize=(15,3))

# Histograma
sns.histplot(data=df_setosa, x=var, label="Setosa", ax=ax[0])
sns.histplot(data=df_versicolor, x=var, label="Versicolor", ax=ax[0])
sns.histplot(data=df_virginica, x=var, label="Virginica", ax=ax[0])
ax[0].set_xlabel(var_titulo)
ax[0].set_ylabel("Frecuencia")
ax[0].legend()

# Densidad
sns.kdeplot(data=df_setosa, x=var, label="Setosa", ax=ax[1])
sns.kdeplot(data=df_versicolor, x=var, label="Versicolor", ax=ax[1])
sns.kdeplot(data=df_virginica, x=var, label="Virginica", ax=ax[1])
ax[1].set_xlabel(var_titulo)
ax[1].set_ylabel("Densidad")
ax[1].legend()

# # Boxplot
# sns.boxplot(data=df_setosa, x=var, label="Setosa", ax=ax[2])
# sns.boxplot(data=df_versicolor, x=var, label="Versicolor", ax=ax[2])
# sns.boxplot(data=df_virginica, x=var, label="Virginica", ax=ax[2])
# ax[2].set_xlabel(var_titulo)
# ax[2].set_title(var_titulo)

plt.show()
# Out:
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %% [markdown]
# ## 1vs2

# %%
plt.figure(figsize=(5,5))

sns.scatterplot(data=df, x="LSepal", y="ASepal", hue="species")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 3vs4

# %% [markdown]
# ## Varoables vs speies

# %%
sns.pairplot(df, hue="species") 
plt.show()
# Out:
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %% [markdown]
# ## Correlacion

# %%
df2 = df[["LSepal","ASepal","LPetal","APetal"]].corr()

# %%
fig = plt.figure(figsize=(6,4))
sns.heatmap(df2.corr(), annot=True, cmap="Blues")
# Out:
# <Axes: >

# %% [markdown]
# # Exploración inicial del dataframe:
# * -Dimensiones
# * -Nulos -> si hay, preprocesamiento
# * -Asimetria/Curtosis
# * -Info
