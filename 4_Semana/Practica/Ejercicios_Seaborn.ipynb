# %% [markdown]
# # Ejercicios de visualización Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

pokemon = pd.read_csv('pokemon.csv', sep =",")

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ## 1. Haz un countplot con el número de pokémons en cada generación

# %%
fig, ax = plt.subplots(figsize=(6,4))
sns.countplot(x="Generation" ,data=pokemon, palette="Blues_r")
plt.show()

# %% [markdown]
# ## 2. Representar la frecuencia de pokémons por tipo 1 en un gráfico de barras.

# %%
fig, ax = plt.subplots (figsize=(15,6))
sns.histplot(data=pokemon["Type 1"])
# Out:
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Type 1', ylabel='Count'>

# %% [markdown]
# ## 3. Haz un diagrama de barras con el número de pokémons tipo 1 igual a "Grass" o "Fire"

# %%
fig, axes = plt.subplots(figsize=(15,8))
pokemon_3 = pokemon[(pokemon["Type 1"]=="Fire") | (pokemon["Type 1"]=="Grass")]
sns.countplot(x="Type 1",data=pokemon_3, palette="pastel")
# Out:
# <Axes: xlabel='Type 1', ylabel='count'>

# %% [markdown]
# ## 4. Haz un histograma con los puntos de salud HP de los pokémons, utiliza el color verde

# %%
fig, ax = plt.subplots (figsize=(15,6))
sns.histplot(data=pokemon["HP"], color="Green")
# Out:
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='HP', ylabel='Count'>

# %% [markdown]
# ## 5. Haz un histograma con la frecuencia de pokémons por rapidez (Speed).

# %%
fig, ax = plt.subplots (figsize=(15,6))
sns.histplot(data=pokemon["Speed"], color="Beige", bins=150)
# Out:
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Speed', ylabel='Count'>

# %% [markdown]
# ## 6. Haz un histograma con los puntos de salud (HP) de los pokémons (Type 1) = "Fire"

# %%
fig, ax = plt.subplots (figsize=(6,3))
sns.histplot(data=pokemon["HP"][pokemon["Type 1"]=="Fire"], color="Green")
# Out:
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='HP', ylabel='Count'>

# %% [markdown]
# ## 7. Haz un scatter plot y un hex plot con los valores de "Attack" y "Defense"de los pokémons

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(data=pokemon, x="Attack", y="Defense")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(3,3))
sns.jointplot(x="Attack", y="Defense", data=pokemon, kind="hex")
plt.show
# Out:
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 8. Haz un scatter hex plot con los valores de "Attack" y "Defense"de los pokémons tipo "Water" y "Fire"

# %%
plt.figure(figsize=(5,5))
sns.jointplot(x="Attack", y="Defense", data=pokemon[(pokemon["Type 1"]=="Fire") | (pokemon["Type 1"]=="Water")], kind="hex")
plt.show
# Out:
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 9. Haz un KDE plot con la salud y el ataque de los pokémons

# %%
plt.figure(figsize=(5,5))
sns.kdeplot(data=pokemon, x="HP", y="Attack", fill=True)
plt.show()
# Out:
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## 10. Haz una grafica de caja con el ataque de los pokémons legendarios y no legendarios.

# %%
fig, ax = plt.subplots (figsize=(3,5))
sns.boxplot(data=pokemon, x="Legendary", y="Attack", width=0.2)
# Out:
# <Axes: xlabel='Legendary', ylabel='Attack'>

# %% [markdown]
# ## 11. Haz una grafica de violin con el ataque de los pokémons legendarios y no legendarios.

# %%
sns.catplot(x="Legendary", y="Attack", data=pokemon, kind="violin")
plt.show()

# %% [markdown]
# ## 12. Obtén un Displot plot del ataque para legendarios y no legendarios (en columnas) y por generaciones en cada fila.

# %%
sns.displot(data=pokemon, x="Attack", row="Generation", col="Legendary")
plt.show()
# Out:
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## 13. Haz un pairplot y compara los puntos de salud (HP), el ataque y la defensa de los pokémons.

# %%
sns.pairplot(pokemon, vars=["HP", "Attack","Defense"]) 
plt.show()
# Out:
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# e:\Apps\ANACONDA\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## 14. Haz boxplots de la variable `'Total'` distiguiendo por generación y entre legendarios y no legendarios.

# %%
fig, ax = plt.subplots (figsize=(8,6))
#Boxplot
sns.boxplot(data=pokemon, x="Generation", y="Total", hue="Legendary", width=0.4)
# Out:
# <Axes: xlabel='Generation', ylabel='Total'>

# %% [markdown]
# ## 15. Haz un heatmap para comparar la correlación entre salud, ataque, ataque especial, defensa, defensa especial y velocidad.

# %%
pokemon_cor = pokemon[["HP","Sp. Atk","Attack","Defense","Sp. Def","Speed"]].corr()
fig, ax = plt.subplots (figsize=(8,6))

sns.heatmap(pokemon_cor, annot=True, cmap="Blues")
# Out:
# <Axes: >

# %% [markdown]
# ## 16. Encontrar los 5 mejores pokémons con respecto a la columna "Total", del tipo "Electric", "Fire", "Water" y comparar su salud, ataque, defensa y velocidad en un mapa de calor

# %%
pokemon_top5_1 = pokemon.sort_values(by="Total", ascending=False).groupby("Type 1").head(5)

# %%
pokemon_cor_top5_1 = pokemon_top5_1[["HP","Attack","Defense","Speed"]].corr()
fig, ax = plt.subplots (figsize=(8,6))

sns.heatmap(pokemon_cor_top5_1, annot=True, cmap="Greens")
# Out:
# <Axes: >

# %%
pokemon_top5_1 = pokemon.sort_values(by="Total", ascending=False).groupby("Type 1").head(5)
pokemon_top5_2 = pokemon.sort_values(by="Total", ascending=False).groupby("Type 2").head(5)
pokemon_top5 = pd.concat([pokemon_top5_1, pokemon_top5_2])
pokemon_top5 = pokemon_top5.drop_duplicates()
# no terminaod para ver los dos tipos
# Out:
#        #                   Name    Type 1    Type 2  Total   HP  Attack  \
# 426  384  RayquazaMega Rayquaza    Dragon    Flying    780  105     180
# 163  150    MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# 164  150    MewtwoMega Mewtwo Y   Psychic       NaN    780  106     150
# 422  382    KyogrePrimal Kyogre     Water       NaN    770  100     150
# 424  383  GroudonPrimal Groudon    Ground      Fire    770  100     180
# ..   ...                    ...       ...       ...    ...  ...     ...
# 379  347                Anorith      Rock       Bug    355   45      95
# 184  170               Chinchou     Water  Electric    330   75      38
# 501  451                Skorupi    Poison       Bug    330   40      50
# 764  694             Helioptile  Electric    Normal    289   44      38
# 790  714                 Noibat    Flying    Dragon    245   40      30
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...
