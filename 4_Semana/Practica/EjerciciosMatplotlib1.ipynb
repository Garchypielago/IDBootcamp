# %% [markdown]
# # Ejercicios de matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Gráfica una recta de (-7,-7) a (7,7) de color rosa

# %%
x = np.linspace(-7,7,20)
y = x

plt.plot(x,y,color="pink")

# %% [markdown]
# ## 2. Obtén el siguiente resultado utilizando subplot y la ecuación anterior

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.linspace(-7,7,20)
y = x

for i, co in enumerate(["pink", "blue", "red", "magenta"]):
    plt.subplot(2,2,i+1)
    plt.plot(x,y,color=co)

# %% [markdown]
# ## 3. Obtén la siguiente gráfica de barras

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Grafica de barras
etiquetas=["a","b", "c", "d"]
valores=[10, 20, 30, 40]
plt.bar(etiquetas, valores, color=["blue","yellow","cyan","magenta"])
plt.show()

# %% [markdown]
# ## 4. Obtener la siguiente gráfica

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig, ax = plt.subplots(figsize=(8,8)) 

letras = ["a","b","c","d"] 
cyans = [10,20,30,40] 
magentas = [20,30,40,50] 

x = np.arange(len(letras))  

ancho = 0.5

plt.bar(x-0.25, cyans, ancho, color="cyan")

plt.bar(x + 0.25, magentas, width = ancho ,color="magenta", alpha=1) 

ax.set_xticks(x) 
ax.set_xticklabels(letras)
plt.show()

# %% [markdown]
# ## 5. Obtener el histograma del último atributo del dataset de la iris plant

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import seaborn as sns
iris=sns.load_dataset("iris")
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
plt.hist(iris.iloc[:,-2], bins=30, color="magenta") 
plt.show()

# %% [markdown]
# ## 6. Muestra los histogramas de los últimos dos atributos de la iris plant

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.hist(iris.iloc[:,-3], bins=20, alpha=0.4, color="magenta")
plt.hist(iris.iloc[:,-2], bins=20, alpha=0.4, color="cyan")
plt.show()

# %% [markdown]
# ## 7. Guarda el dataset de titanic en una variable

# %%
titanic=sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## 8. Muestra en una grafica de barras el número de hombres y mujeres que sobrevivieron

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
supervivientes = titanic[titanic.survived==1].sex.value_counts()

plt.bar(supervivientes.index , supervivientes.values, color="green", width=0.5)
plt.show()

# %% [markdown]
# ## 9. Muestra en una grafica de barras agrupada la cantidad de hombres y mujeres que sobrevivieron y la cantidad de los que no sobrevivieron

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
fig, ax = plt.subplots(figsize=(6,6)) 

supervivientes = titanic[titanic.survived==1].sex.value_counts().sort_index()
no_supervivientes = titanic[titanic.survived==0].sex.value_counts().sort_index()

x = np.arange(2) 

plt.bar(x - 0.2 , supervivientes.values, color="blue", width=0.4)
plt.bar(x + 0.2, no_supervivientes.values, width = 0.4 ,color="red") 

ax.set_xticks(x) 
ax.set_xticklabels(supervivientes.index)
plt.show()

# %% [markdown]
# ## 10. Muestra en una grafica de barras agrupada la cantidad de hombres y mujeres de cada clase (Pclass)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
fig, ax = plt.subplots(figsize=(5,5)) 

m1 = titanic[titanic["class"]=="First"].sex.value_counts().sort_index()
m2 = titanic[titanic["class"]=="Second"].sex.value_counts().sort_index()
m3 = titanic[titanic["class"]=="Third"].sex.value_counts().sort_index()

x = np.arange(2) 

plt.bar(x - 0.2 , m1.values, color="blue", width=0.2)
plt.bar(x, m2.values, width = 0.2 ,color="red") 
plt.bar(x + 0.2, m3.values, width = 0.2,color="green") 

ax.set_xticks(x) 
ax.set_xticklabels(m1.index)
plt.show()

# %% [markdown]
# ## 11. Muestra en una gráfica el número de sobrevivientes por clase (Pclass)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig, ax = plt.subplots(figsize=(5,3)) 

super_clase = titanic[titanic.survived==1]["class"].value_counts().sort_index()

x = np.arange(titanic["class"].unique().size) 

plt.bar(super_clase.index , super_clase.values, width=0.5, color=["blue","green","red"])
plt.show()

# %% [markdown]
# ## 12. Muestra en una gráfica lineal las edades de los pasajeros que sobrevivieron y en otra la de los pasajeros que no sobrevivieron

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig, ax = plt.subplots(figsize=(20,3)) 

y = titanic[titanic["survived"]==1].age
z = titanic[titanic["survived"]==0].age
ax.plot(y, label="Supervivientes", color="green")  
ax.plot(z, label="Fallecidos", color="red")  
ax.legend()
ax.set_xlabel("Index")
ax.set_ylabel("Edad")
plt.show()

# %% [markdown]
# ## 13. Muestra en una grafica de caja la edad de los que sobrevivieron y de los que no sobrevivieron
#
#
# Nota: Para poder graficarlo hay que reemplazar los NaN por el promedio de edad.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
titanic.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False

# %%
edadmedia = titanic.age.mean(skipna=True)
titanic.age.replace(np.nan, int(edadmedia),  inplace=True)

# %%
edad = titanic.columns.get_loc("age")
supervi = titanic[titanic["survived"]==1].iloc[:,edad]
no_supervi = titanic[titanic["survived"]==0].iloc[:,edad]

sup_edad = [ no_supervi, supervi ]
titulos = ["Fallecidos", "Supervivientes"]

fig, ax = plt.subplots(figsize=(4,4))
ax.boxplot(sup_edad, labels=titulos)
plt.show()

# %% [markdown]
# ## 14. Mostrar en una gráfica de caja por clase la edad de los pasajeros

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
edad = titanic.columns.get_loc("age")
c1 = titanic[titanic["class"]=="First"].iloc[:,edad]
c2 = titanic[titanic["class"]=="Second"].iloc[:,edad]
c3 = titanic[titanic["class"]=="Third"].iloc[:,edad]

class_edad = [ c1,c2,c3 ]
titulos2 = ["Clase 1", "Clase 2", "Clase 3"]

fig, ax = plt.subplots(figsize=(4,4))
ax.boxplot(class_edad, labels=titulos2)
plt.show()

# %% [markdown]
# ## 15. Muestra en una gráfica de dispersión (scatter) la edad de los pasajeros vs el costo de su ticket

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
costo = titanic.columns.get_loc("fare")
edad = titanic.columns.get_loc("age")
plt.scatter(titanic.iloc[:,edad],titanic.iloc[:,costo])
plt.show()

# %% [markdown]
# ## 16. Muestra en una gráfica de dispersión la clase vs el  el precio del ticket

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
costo = titanic.columns.get_loc("fare")
clase = titanic.columns.get_loc("class")
plt.scatter(titanic.iloc[:,clase],titanic.iloc[:,costo])
plt.show()

# %% [markdown]
# ## 17. Muestra en un histograma la edad de los pasajeros que sobrevivieron y la edad de los que no

# %%
edad = titanic.columns.get_loc("age")
plt.hist(titanic[titanic.survived==1].iloc[:,edad], bins=20, alpha=0.5, color="magenta")
plt.hist(titanic[titanic.survived==0].iloc[:,edad], bins=20, alpha=0.5, color="cyan")
plt.show()

# %% [markdown]
# ## 18. Muestra en un histograma el costo de boleto por clase

# %%
costo = titanic.columns.get_loc("fare")
plt.hist(titanic[titanic["class"]=="First"].iloc[:,costo], bins=50, alpha=0.5, color="magenta")
plt.hist(titanic[titanic["class"]=="Second"].iloc[:,costo], bins=50, alpha=0.5, color="cyan")
plt.hist(titanic[titanic["class"]=="Third"].iloc[:,costo], bins=50, alpha=0.5, color="beige")
plt.show()
