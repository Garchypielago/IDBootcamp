# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# <font size="3"><a href='https://www.linkedin.com/in/adrianceja/'> <span style="color: #5E62D1;"> <strong> Adrián Y. Ceja Flores</strong></span></a></font>
#
# <font size="3"><a href='https://www.instagram.com/p/CKzW3I1sOkV/'><span style="color: #5E62D1;"><strong>Alfonso D. Blázquez</strong></span></a></font>

# %% [markdown]
# <font size="7"><span style="color: #33D6CC;">Ejercicios de sets</span></font>

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 1. Convierte la siguiente lista en set.</span></font>

# %%
x = ["Madrid", "Bilbao", "Valencia", "Bilbao", "Valencia", "Zaragoza"]
x
# Out:
# ['Madrid', 'Bilbao', 'Valencia', 'Bilbao', 'Valencia', 'Zaragoza']

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 2. Repite el ejercicio anterior e imprime el número de elementos que se eliminan.</span></font>

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 3. Utilizando el bucle <strong>for</strong> para realizar una intersección de conjuntos a las siguientes listas:</span></font>

# %%
lista1 = [1,2,3,4]
lista2 = [4,5,6,7]

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 4. Realiza la intersección de las siguientes frases (palabras en cómun) haciendo uso de sets.</span></font>

# %%
frase1 = 'Erase una vez en un universo lejano'
frase2 = 'En el lejano oeste'

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 5. Calcula la diferencia entre los siguientes sets (ejemplo: set1.difference(set2)) haciendo uso de un bucle for y no del método difference(). Comprueba el resultado apoyándote en la función difference() </span></font>

# %%
set1 = {9,8,7,6,5,4,3,2}
set2 = {9,8,10}

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 6. Genera un set a partir de la unión de los set1 y set2 del ejercicio anterior sin hacer uso de la función union, ni update (puedes utilizar un bucle for) </span></font>

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 7. Realiza las siguientes tareas a partir del set llamado, mi_set:  </span></font>
# <ul>
# <font size="3"><li><span style="color: #5E62D1;">Pide al usuario que ingrese 3 empresas de tecnología y añade estos elementos al set. Nota: utiliza la función input() para pedir al usuario información.</span></li></font>
# <font size="3"><li><span style="color: #5E62D1;">Comprueba si se ha introducido alguna empresa repetida o no</span></li></font>
# </ul>

# %%
mi_set = {'Facebook', 'Google', 'Apple'}

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 8. Repite el ejercicio anterior pero ahora imprime el número de veces que se repitio una empresa que ya existia en el set y se intento agregar al set.</span></font>

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 9. Utiliza un bucle while para agregar a un set vacío los números del -25 al 50.</span></font>

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 10. Ordena el siguiente set de menor a mayor: {5,4,3,2,1}.</span></font>
