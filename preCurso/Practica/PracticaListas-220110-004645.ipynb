# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font size="3"><a href='https://www.linkedin.com/in/adrianceja/'> <span style="color: #5E62D1;"> <strong> Adrián Y. Ceja Flores</strong></span></a></font>
#
# <font size="3"><a href='https://www.instagram.com/p/CKzW3I1sOkV/'><span style="color: #5E62D1;"><strong>Alfonso D. Blázquez</strong></span></a></font>

# %% [markdown]
# <font size="7"><span style="color: #33D6CC;">Ejercicios de listas</span></font>

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 1. Obtén a partir de la siguiente lista, 3 listas diferentes.  </span></font>
# <ul>
# <font size="3"><li><span style="color: #5E62D1;">Una lista para los elementos enteros</span></li></font>
# <font size="3"><li><span style="color: #5E62D1;">Una lista para los elementos booleanos</span></li></font>
# <font size="3"><li><span style="color: #5E62D1;">Una lista para los elementos string</span></li></font>
# </ul>

# %%
lista  = ["a","b","c","d","e",1,2,3,4,5,False,True]

# %%
listaBoolean = lista[-2:]
print(listaBoolean)

listaString = lista[0:5]
print(listaString)

listaInt = lista[5:-2]
print(listaInt)
# Out:
# [False, True]
# ['a', 'b', 'c', 'd', 'e']
# [1, 2, 3, 4, 5]

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 2. Agrega las vocales faltantes a la lista de elementos string del ejercicio anterior.  </span></font>

# %%
listaString.extend(['i','o','u'])
listaString
# Out:
# ['a', 'b', 'c', 'd', 'e', 'i', 'o', 'u']

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 3. Elimina las consonantes de la lista de elementos string del ejercicio 2.  </span></font>

# %%
listaString.pop(1)
listaString.pop(1)
listaString.pop(1)
listaString
# Out:
# ['a', 'e', 'i', 'o', 'u']

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 4. Aplica el método reverse a la lista de enteros que se obtuvo en el ejercicio 1.  </span></font>

# %%
listaInt.sort(reverse=True)
listaInt
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 5. Aplica el método sort() para ordenar la lista de números enteros de mayor a menor. </span></font>

# %%
listaInt.sort(reverse=True)
listaInt
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 6. Crea una copia de la lista del ejercicio 5 y elimina los elementos que se encuentren en un índice par.  </span></font>

# %%
listaInt2 = listaInt.copy()[1::2]
listaInt2
# Out:
# [4, 2]

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 7. Utiliza indexación para remplazar los elementos de la lista que se obtuvo en el ejercicio 3 por nombres de personas.</span></font>
#
# <font size="3"><span style="color: #5E62D1;"> Tomando en cuenta que si vas a reemplazar una letra "e" el nombre debe de comenzar con la letra "e".  </span></font>

# %%
listaString = ['Alejandro','Ernesto','Sergio','Adrian','Juan']
listaString
# Out:
# ['Alejandro', 'Ernesto', 'Sergio', 'Adrian', 'Juan']

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 8. Crea una copia de la lista del ejercicio 5 y elimina los elementos que se encuentren en un índice par.  </span></font>

# %%
listaInt3 = listaInt.copy()[0::2]
listaInt3
# Out:
# [5, 3, 1]

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 9. Convierte cada palabra de la siguiente frase en un elemento de una lista: "La vida es bella". Guarda la lista en una variable e imprime la variable.  </span></font>

# %%
listaVida = ("La vida es bella").split()
listaVida
# Out:
# ['La', 'vida', 'es', 'bella']

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 10. De la lista del ejercicio 9, encuentra el índice o posición donde se encuentra la palabra "bella".  </span></font>

# %%
print(listaVida.index("bella"))
# Out:
# 3

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 11. De la siguiente lista, convierte cada elemento a tipo entero e imprime la lista resultante.  </span></font>

# %%
lista = ["10", "30", "50", "100"]
lista
# Out:
# ['10', '30', '50', '100']

# %%
lista = [10, 30, 50, 100]
lista
# Out:
# [10, 30, 50, 100]

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 12. De la siguiente lista, encuentra los índices de los elementos de tipo booleano, guardalos en una lista e imprime la lista.  </span></font>

# %%
lista = ["True", True, "False", "10.5", False, 3.1416, "False", False]
lista
# Out:
# ['True', True, 'False', '10.5', False, 3.1416, 'False', False]

# %%
print(lista.index(True))
print(lista.index(False))
listaTF = [lista[1], lista[4], lista[7]]
listaTF
# Out:
# 1
# 4
# [True, False, False]

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 13. Crea una sola lista a partir de las siguientes listas.  </span></font>

# %%
lista1 = [1,2,3,4,5]
lista2 = ["a","b","c","d","e"]

# %%
lista3 = lista1+lista2
lista3
# Out:
# [1, 2, 3, 4, 5, 'a', 'b', 'c', 'd', 'e']

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 14. Crea una lista de listas con las siguientes listas.  </span></font>

# %%
lista1 = [1,2,3,4,5]
lista2 = ["a","b","c","d","e"]
lista3 = [True, False]
lista4 = [[1],[2],[3]]

# %%
lista5 = lista1+lista2+lista3+lista4
lista5
# Out:
# [1, 2, 3, 4, 5, 'a', 'b', 'c', 'd', 'e', True, False, [1], [2], [3]]

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 15. Utiliza slicing con índices negativos para obtener la siguiente sublista de la lista llamada lista_A. Sublista:  [2.5, -66.4, -97.3]. </span></font>

# %%
lista_A = [1.5, True, False, 2.5, -15 -51.4, -97.3, False, True]
lista_A
lista_A.index(2.5)
Sublista = lista_A[-5:-2:]
Sublista
# Out:
# [2.5, -66.4, -97.3]

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 16. Del ejercicio anterior (lista_A) agrega el sigueinte elemento en la posición 5 de la lista: True.  </span></font>

# %%
lista_A[1] = 5
lista_A
# Out:
# [1.5, 5, False, 2.5, -66.4, -97.3, False, True]

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 17. De la siguiente lista intercambia el primer elemento por el último de posición.  </span></font>

# %%
lista = [True, 5, 5, 5, False]

# %%
lista.reverse()
lista
# Out:
# [False, 5, 5, 5, True]

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 18. Repite el ejercicio anterior utilizando un método distinto.  </span></font>

# %%
V1 = lista[0]
lista[0] = lista[len(lista)-1]
lista[len(lista)-1] = V1
lista
# Out:
# [True, 5, 5, 5, False]

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 19. Ordena cada lista en orden alfabetico de la siguiente lista e imprime cada lista por separado.  </span></font>

# %%
empresas = [["CocaCola","Pepsi"],["FB","TW","IG"],["Ferrari","Audi","Ford","Nissan"],["KLM","AA","Iberia","AE","Avianca"]]
empresas
# Out:
# [['CocaCola', 'Pepsi'],
#  ['FB', 'TW', 'IG'],
#  ['Ferrari', 'Audi', 'Ford', 'Nissan'],
#  ['KLM', 'AA', 'Iberia', 'AE', 'Avianca']]

# %%
empresas[0].sort()
empresas[1].sort()
empresas[2].sort()
empresas[3].sort()
print(empresas[0])
print(empresas[1])
print(empresas[2])
print(empresas[3])
# Out:
# ['CocaCola', 'Pepsi']
# ['FB', 'IG', 'TW']
# ['Audi', 'Ferrari', 'Ford', 'Nissan']
# ['AA', 'AE', 'Avianca', 'Iberia', 'KLM']

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 20. Obtén de las listas del ejercicio anterior, los siguientes elementos utilizando indexación y crea una nueva lista con dichos elementos. </span></font>
#
# <ul>
# <font size="3"><li><span style="color: #5E62D1;">Audi</span></li></font>
# <font size="3"><li><span style="color: #5E62D1;">Avianca</span></li></font>
# <font size="3"><li><span style="color: #5E62D1;">KLM</span></li></font>
# </ul>

# %%
empresas2 = [empresas[2][empresas[2].index('Audi')],empresas[3][empresas[3].index('Avianca')],empresas[3][empresas[3].index('KLM') ]]
empresas2
# Out:
# ['Audi', 'Avianca', 'KLM']
