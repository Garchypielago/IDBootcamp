# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# <font size="3"><a href='https://www.linkedin.com/in/adrianceja/'> <span style="color: #5E62D1;"> <strong> Adrián Y. Ceja Flores</strong></span></a></font>
#
# <font size="3"><a href='https://www.instagram.com/p/CKzW3I1sOkV/'><span style="color: #5E62D1;"><strong>Alfonso D. Blázquez</strong></span></a></font>

# %% [markdown]
# <font size="7"><span style="color: #33D6CC;">Ejercicios de strings</span></font>

# %%
frase = 'Después de escalar una gran colina, uno se encuentra sólo con que hay muchas más colinas que escalar.'

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 1. Obtén a partir de la frase anterior:  </span></font>
# <ul>
# <font size="3"><li><span style="color: #5E62D1;">Su número de caracteres</span></li></font>
# <font size="3"><li><span style="color: #5E62D1;">El punto final de la frase en una variable</span></li></font>
# <font size="3"><li><span style="color: #5E62D1;">Una lista con cada una de las palabras</span></li></font>
# </ul>

# %%
print(len(frase))
# Out:
# 101

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 2. Obtén la sección "gran colina" haciendo slicing y guardalo en una variable llamada subfrase1</span></font>

# %%
frase.find('gran colina')
subfrase1 = frase[23:34]

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 3. Obtén la sección "más colinas" haciendo slicing negativo y guardalo en una variable llamada subfrase2</span></font>

# %%
frase.find('más colinas')
subfrase2 = frase[-24:-13]

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 4. Crea la siguiente frase utilizando las variables subfrase1 y subfrase2: "gran colina, más colinas, gran colina" </span></font>

# %%
subfrase3 = subfrase1 + ', '+ subfrase2 + ', '+ subfrase1

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 5. Aplica stride de paso 2 a la frase hasta la primera ',' </span></font>

# %%
print(frase[:frase.find(','):2])
print(frase[:frase.find(',')+1:2])
# Out:
# Dsusd saa n rncln
# Dsusd saa n rncln,

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 6. Comprueba si la frase empieza con la palabra 'Hola'</span></font>

# %%
print(frase.startswith('Hola'))
# Out:
# False

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 7. Crea una nueva variable, frase2, que tenga la frase en mayúsculas.</span></font>

# %%
frase2 = frase.upper()

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 8. Reemplaza la palabra "colina" por "montaña" en la variable frase2. </span></font>

# %%
print(frase2.replace("COLINA","MONTAÑA"))
# Out:
# DESPUÉS DE ESCALAR UNA GRAN MONTAÑA, UNO SE ENCUENTRA SÓLO CON QUE HAY MUCHAS MÁS MONTAÑAS QUE ESCALAR.

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 9. Añade un espacio al inicio y otro al final de la frase. </span></font>

# %%
frase3 = ' '+frase+' '
print(frase3)
# Out:
#  Después de escalar una gran colina, uno se encuentra sólo con que hay muchas más colinas que escalar.

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 10. Utiliza la función strip() para eliminar los espacios que has añadido en el ejercicio anterior.  </span></font>

# %%
frase3 = frase3.strip(' ')

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 11. Encontrar las veces que aparece la cadena 'ol' en la frase. (el resultado debería ser 2)</span></font>

# %%
print(frase.count('ol'))
# Out:
# 2
