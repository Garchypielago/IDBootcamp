# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

# %%
train=pd.read_csv("train.csv")

# %%
# Tiro la columna id, course en train
train=train.drop(columns=['id','Course'])

# %%
train.head()
# Out:
#    Marital status  Application mode  Application order  \
# 0               1                 1                  1
# 1               1                17                  1
# 2               1                17                  2
# 3               1                 1                  3
# 4               1                 1                  2
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           126.0            1                       1
# 1                           125.0            1                      19
# 2                           137.0            1                       3
# ...

# %%
colnames=train.columns

# %%
colnames
# Out:
# Index(['Marital status', 'Application mode', 'Application order',
#        'Daytime/evening attendance', 'Previous qualification',
#        'Previous qualification (grade)', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Admission grade',
#        'Displaced', 'Educational special needs', 'Debtor',
#        'Tuition fees up to date', 'Gender', 'Scholarship holder',
#        'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
# ...

# %%
train[['Curricular units 1st sem (credited)',
       'Curricular units 1st sem (enrolled)',
       'Curricular units 1st sem (evaluations)',
       'Curricular units 1st sem (approved)',
       'Curricular units 1st sem (grade)',
       'Curricular units 1st sem (without evaluations)',
       'Curricular units 2nd sem (credited)',
       'Curricular units 2nd sem (enrolled)',
       'Curricular units 2nd sem (evaluations)',
       'Curricular units 2nd sem (approved)',
       'Curricular units 2nd sem (grade)',
       'Curricular units 2nd sem (without evaluations)']]
# Out:
#        Curricular units 1st sem (credited)  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...                                    ...
# 76513                                    0
# 76514                                    0
# 76515                                    0
# 76516                                    0
# 76517                                    0
#
#        Curricular units 1st sem (enrolled)  \
# 0                                        6
# 1                                        6
# 2                                        6
# 3                                        7
# 4                                        7
# ...                                    ...
# 76513                                    6
# 76514                                    6
# 76515                                    5
# ...

# %%
"hola adios".startswith("hola")
# Out:
# False

# %%
[col for col in colnames if col.startswith("Curricular")]
# Out:
# ['Curricular units 1st sem (credited)',
#  'Curricular units 1st sem (enrolled)',
#  'Curricular units 1st sem (evaluations)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (grade)',
#  'Curricular units 1st sem (without evaluations)',
#  'Curricular units 2nd sem (credited)',
#  'Curricular units 2nd sem (enrolled)',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 2nd sem (approved)',
#  'Curricular units 2nd sem (grade)',
#  'Curricular units 2nd sem (without evaluations)']

# %%
curricular_columns = [col for col in colnames if col.startswith("Curricular units 1st")]

# %%
train[curricular_columns].head()
# mi primer pensamiento es que tiene que haber una relación entre las columnas
# pero no entiendo bien que significa cada cosa
# Out:
#    Curricular units 1st sem (credited)  Curricular units 1st sem (enrolled)  \
# 0                                    0                                    6
# 1                                    0                                    6
# 2                                    0                                    6
# 3                                    0                                    7
# 4                                    0                                    7
#
#    Curricular units 1st sem (evaluations)  \
# 0                                       6
# 1                                       8
# 2                                       0
# 3                                       9
# 4                                      12
#
#    Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# 0                                    6                         14.500000
# 1                                    4                         11.600000
# ...

# %%
train.loc[train['Curricular units 1st sem (credited)']>0,curricular_columns].head()
# veo que en credited siempre hay 0, que pasa si no hay 0?
# puedo pensar que credited son como los cursos que me dan creditos, alomejor credited siempre es menor que otra columna
# voy a compararlo
# Out:
#     Curricular units 1st sem (credited)  Curricular units 1st sem (enrolled)  \
# 25                                   14                                   15
# 42                                    2                                    6
# 71                                    1                                    7
# 80                                    3                                    6
# 83                                    2                                    6
#
#     Curricular units 1st sem (evaluations)  \
# 25                                      16
# 42                                       6
# 71                                      14
# 80                                       7
# 83                                       9
#
#     Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# 25                                   15                         10.923077
# 42                                    6                         13.833333
# ...

# %%
# comparación con enrolled
train.loc[train['Curricular units 1st sem (credited)']>train['Curricular units 1st sem (enrolled)'],curricular_columns].head()
# Out:
#        Curricular units 1st sem (credited)  \
# 5046                                    20
# 50201                                   11
# 54312                                    7
# 60743                                    8
# 69915                                   19
#
#        Curricular units 1st sem (enrolled)  \
# 5046                                    19
# 50201                                    8
# 54312                                    6
# 60743                                    7
# 69915                                   18
#
#        Curricular units 1st sem (evaluations)  \
# 5046                                       23
# 50201                                      11
# 54312                                      15
# 60743                                      15
# 69915                                      12
#
#        Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# ...

# %%
# comparación con approved
train.loc[train['Curricular units 1st sem (credited)']>train['Curricular units 1st sem (approved)'],curricular_columns].head()
# Out:
#       Curricular units 1st sem (credited)  \
# 1975                                    5
# 2111                                   15
# 2132                                    9
# 3066                                   13
# 4816                                    7
#
#       Curricular units 1st sem (enrolled)  \
# 1975                                    9
# 2111                                   15
# 2132                                   13
# 3066                                   22
# 4816                                   10
#
#       Curricular units 1st sem (evaluations)  \
# 1975                                      14
# 2111                                      16
# 2132                                      14
# 3066                                      33
# 4816                                      14
#
#       Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# 1975                                    0                          0.000000
# ...

# %%
# comparación con evaluations
train.loc[train['Curricular units 1st sem (credited)']>train['Curricular units 1st sem (evaluations)'],curricular_columns].head()
# Out:
#        Curricular units 1st sem (credited)  \
# 19626                                    9
# 24318                                   18
# 43258                                   12
# 47450                                   12
# 59160                                   12
#
#        Curricular units 1st sem (enrolled)  \
# 19626                                   12
# 24318                                   18
# 43258                                   14
# 47450                                   17
# 59160                                   14
#
#        Curricular units 1st sem (evaluations)  \
# 19626                                       7
# 24318                                      17
# 43258                                      11
# 47450                                      11
# 59160                                       7
#
#        Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# ...

# %%
# parece que no es necesariamente menor que las otras columnas

# %%
# compruevo algo que para mi tiene sentido, que el numero de aprovadas es menor a enrolled
train.loc[train['Curricular units 1st sem (approved)'] > train['Curricular units 1st sem (enrolled)'], curricular_columns].head()
# hay filas con mas approved que enrolled :O
# Out:
#       Curricular units 1st sem (credited)  \
# 1891                                    2
# 2151                                    9
# 2311                                    7
# 4565                                    0
# 4695                                    0
#
#       Curricular units 1st sem (enrolled)  \
# 1891                                    7
# 2151                                   11
# 2311                                   11
# 4565                                    7
# 4695                                    7
#
#       Curricular units 1st sem (evaluations)  \
# 1891                                      13
# 2151                                      21
# 2311                                      16
# 4565                                      14
# 4695                                       8
#
#       Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# 1891                                    8                         14.666667
# ...

# %% [markdown]
# # Categoricas

# %%
train['Application order'].value_counts()
# Out:
# Application order
# 1    54381
# 2     8875
# 3     5364
# 4     3822
# 5     2125
# 6     1947
# 0        3
# 9        1
# Name: count, dtype: int64

# %%
train["Nacionality"].value_counts()
# Out:
# Nacionality
# 1      76013
# 41       221
# 26        67
# 6         56
# 22        56
# 24        15
# 11        15
# 2         13
# 103       12
# 105        9
# 101        9
# 100        9
# 21         6
# 25         6
# 62         6
# 17         2
# 109        2
# 32         1
# Name: count, dtype: int64
