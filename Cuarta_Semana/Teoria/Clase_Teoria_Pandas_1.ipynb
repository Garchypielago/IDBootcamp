# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Lectura de datos
# ## seleccionar columnas específicas (Dataframes y Series)
# ## Funciones de columnas
# ## Creación de columnas
# # Selección de filas por filtraje
# ## iloc, loc
# # Cambiar nombres columnas
# #resetear índice
# #Eliminar filas/columnnas
# #crear dataframes

# %%
iris = pd.read_excel("iris.xlsx")

# %%
iris
# Out:
#      Largo Sepalo   Ancho Sepalo   Largo Petalo   Ancho Petalo           Clase
# 0             5.1            3.5            1.4            0.2     Iris-setosa
# 1             4.9            3.0            1.4            0.2     Iris-setosa
# 2             4.7            3.2            1.3            0.2     Iris-setosa
# 3             4.6            3.1            1.5            0.2     Iris-setosa
# 4             5.0            3.6            1.4            0.2     Iris-setosa
# ..            ...            ...            ...            ...             ...
# 145           6.7            3.0            5.2            2.3  Iris-virginica
# 146           6.3            2.5            5.0            1.9  Iris-virginica
# 147           6.5            3.0            5.2            2.0  Iris-virginica
# 148           6.2            3.4            5.4            2.3  Iris-virginica
# 149           5.9            3.0            5.1            1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Out:
# '/content'

# %% [markdown]
# # Seleccionar columnas específicas

# %%
iris[["Largo Sepalo", " Ancho Sepalo"]]
# Out:
#      Largo Sepalo   Ancho Sepalo   Largo Petalo   Ancho Petalo           Clase
# 0             5.1            3.5            1.4            0.2     Iris-setosa
# 1             4.9            3.0            1.4            0.2     Iris-setosa
# 2             4.7            3.2            1.3            0.2     Iris-setosa
# 3             4.6            3.1            1.5            0.2     Iris-setosa
# 4             5.0            3.6            1.4            0.2     Iris-setosa
# ..            ...            ...            ...            ...             ...
# 145           6.7            3.0            5.2            2.3  Iris-virginica
# 146           6.3            2.5            5.0            1.9  Iris-virginica
# 147           6.5            3.0            5.2            2.0  Iris-virginica
# 148           6.2            3.4            5.4            2.3  Iris-virginica
# 149           5.9            3.0            5.1            1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
print(iris.columns)
# Out:
# Index(['Largo Sepalo', ' Ancho Sepalo', ' Largo Petalo', ' Ancho Petalo',
#        ' Clase'],
#       dtype='object')

# %%
iris.head(5) #muestra las primeras 5 filas del dataframe
# Out:
#    Largo Sepalo   Ancho Sepalo   Largo Petalo   Ancho Petalo        Clase
# 0           5.1            3.5            1.4            0.2  Iris-setosa
# 1           4.9            3.0            1.4            0.2  Iris-setosa
# 2           4.7            3.2            1.3            0.2  Iris-setosa
# 3           4.6            3.1            1.5            0.2  Iris-setosa
# 4           5.0            3.6            1.4            0.2  Iris-setosa

# %%
df = pd.read_excel("iris.xlsx", sheet_name=0)
df.head()
# Out:
#    Largo Sepalo   Ancho Sepalo   Largo Petalo   Ancho Petalo        Clase
# 0           5.1            3.5            1.4            0.2  Iris-setosa
# 1           4.9            3.0            1.4            0.2  Iris-setosa
# 2           4.7            3.2            1.3            0.2  Iris-setosa
# 3           4.6            3.1            1.5            0.2  Iris-setosa
# 4           5.0            3.6            1.4            0.2  Iris-setosa

# %%
df.tail(10) #muestra las últimas 5 filas del dataframe
# Out:
#      Largo Sepalo   Ancho Sepalo   Largo Petalo   Ancho Petalo           Clase
# 140           6.7            3.1            5.6            2.4  Iris-virginica
# 141           6.9            3.1            5.1            2.3  Iris-virginica
# 142           5.8            2.7            5.1            1.9  Iris-virginica
# 143           6.8            3.2            5.9            2.3  Iris-virginica
# 144           6.7            3.3            5.7            2.5  Iris-virginica
# 145           6.7            3.0            5.2            2.3  Iris-virginica
# 146           6.3            2.5            5.0            1.9  Iris-virginica
# 147           6.5            3.0            5.2            2.0  Iris-virginica
# 148           6.2            3.4            5.4            2.3  Iris-virginica
# 149           5.9            3.0            5.1            1.8  Iris-virginica

# %%
df.shape #muestra el tamaño del dataframe (dimensiones)
# Out:
# (150, 5)

# %%
len(df)
# Out:
# 150

# %%
df.index #devuelve los índices del dataframe
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.columns
# Out:
# Index(['Largo Sepalo', ' Ancho Sepalo', ' Largo Petalo', ' Ancho Petalo',
#        ' Clase'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Largo Sepalo   Ancho Sepalo   Largo Petalo   Ancho Petalo
# count    150.000000     150.000000     150.000000     150.000000
# mean       5.843333       3.054000       3.758667       1.198667
# std        0.828066       0.433594       1.764420       0.763161
# min        4.300000       2.000000       1.000000       0.100000
# 25%        5.100000       2.800000       1.600000       0.300000
# 50%        5.800000       3.000000       4.350000       1.300000
# 75%        6.400000       3.300000       5.100000       1.800000
# max        7.900000       4.400000       6.900000       2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Largo Sepalo   150 non-null    float64
#  1    Ancho Sepalo  150 non-null    float64
#  2    Largo Petalo  150 non-null    float64
#  3    Ancho Petalo  150 non-null    float64
#  4    Clase         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.sum() #suma el numero de elementos que NO son NaN, de cada columna
# Out:
# Largo Sepalo                                                 876.5
#  Ancho Sepalo                                                458.1
#  Largo Petalo                                                563.8
#  Ancho Petalo                                                179.8
#  Clase           Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# dtype: object

# %%
df[["Largo Sepalo", " Ancho Sepalo"]].sum()
# Out:
# Largo Sepalo     876.5
#  Ancho Sepalo    458.1
# dtype: float64

# %%
df = pd.read_csv("iris.csv")
df
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
type(df[["Largo Sepalo"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df["Largo Sepalo"] #esto devuelve una serie (valores ordenados)
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: Largo Sepalo, Length: 150, dtype: float64

# %%
df[["Largo Sepalo"]] #esto devuelve una dataframe (con índices y columnas)
# Out:
#      Largo Sepalo
# 0             5.1
# 1             4.9
# 2             4.7
# 3             4.6
# 4             5.0
# ..            ...
# 145           6.7
# 146           6.3
# 147           6.5
# 148           6.2
# 149           5.9
#
# [150 rows x 1 columns]

# %%
df
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.Clase

# %%
df["Clase"]
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Clase, Length: 150, dtype: object

# %% [markdown]
# #Funciones de columnas

# %%
#Value Counts
df[["Largo Sepalo", "Ancho Petalo"]].value_counts()
# Out:
# Largo Sepalo  Ancho Petalo
# 5.0           0.2             5
# 4.9           0.1             3
# 4.8           0.2             3
# 5.7           1.3             3
# 6.1           1.4             3
#                              ..
# 5.7           1.2             1
#               1.0             1
#               0.4             1
#               0.3             1
# 7.9           2.0             1
# Name: count, Length: 110, dtype: int64

# %%
df.columns
# Out:
# Index(['Largo Sepalo', 'Ancho Sepalo', 'Largo Petalo', 'Ancho Petalo',
#        'Clase'],
#       dtype='object')

# %%
df[["Largo Sepalo"]].min()
df[["Largo Sepalo"]].sum()
df[["Largo Sepalo"]].max()
df[["Largo Sepalo"]].median()
# Out:
# Largo Sepalo    5.8
# dtype: float64

# %%
df[["Largo Sepalo"]].quantile(0.1)
# Out:
# Largo Sepalo    4.8
# Name: 0.1, dtype: float64

# %%
df["Clase"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# # Creación de columnas

# %%
df["columnaN"]=2
df
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase  \
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
#      columnaN
# 0           2
# 1           2
# ...

# %%
df["Largo Sepalo"].cumsum()
# Out:
# 0        5.1
# 1       10.0
# 2       14.7
# 3       19.3
# 4       24.3
#        ...
# 145    851.6
# 146    857.9
# 147    864.4
# 148    870.6
# 149    876.5
# Name: Largo Sepalo, Length: 150, dtype: float64

# %%
df["suma acumulada LS"] = df["Largo Sepalo"].cumsum()

# %%
df.head()
# Out:
#    Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo        Clase  \
# 0           5.1           3.5           1.4           0.2  Iris-setosa
# 1           4.9           3.0           1.4           0.2  Iris-setosa
# 2           4.7           3.2           1.3           0.2  Iris-setosa
# 3           4.6           3.1           1.5           0.2  Iris-setosa
# 4           5.0           3.6           1.4           0.2  Iris-setosa
#
#    columnaN  suma acumulada LS
# 0         2                5.1
# 1         2               10.0
# 2         2               14.7
# 3         2               19.3
# 4         2               24.3

# %%
del df['columnaN']
df
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase  \
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
#      suma acumulada LS
# 0                  5.1
# ...

# %%
df["KPI 27"] = df["Largo Sepalo"]**2-df["Largo Petalo"]

# %%
df
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase  \
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
#      suma acumulada LS  KPI 27
# ...

# %% [markdown]
# #Selección de filas por filtraje

# %%
df["Largo Sepalo"]>5
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: Largo Sepalo, Length: 150, dtype: bool

# %%
df[df["Largo Sepalo"]>5]
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase  \
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 5             5.4           3.9           1.7           0.4     Iris-setosa
# 10            5.4           3.7           1.5           0.2     Iris-setosa
# 14            5.8           4.0           1.2           0.2     Iris-setosa
# 15            5.7           4.4           1.5           0.4     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
#      suma acumulada LS  KPI 27
# ...

# %%
df[df.Clase=="Iris-virginica"]
df.head()
# Out:
#    Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo        Clase  \
# 0           5.1           3.5           1.4           0.2  Iris-setosa
# 1           4.9           3.0           1.4           0.2  Iris-setosa
# 2           4.7           3.2           1.3           0.2  Iris-setosa
# 3           4.6           3.1           1.5           0.2  Iris-setosa
# 4           5.0           3.6           1.4           0.2  Iris-setosa
#
#    suma acumulada LS  KPI 27
# 0                5.1   24.61
# 1               10.0   22.61
# 2               14.7   20.79
# 3               19.3   19.66
# 4               24.3   23.60

# %%
(df["Largo Sepalo"]>5) & (df["Largo Sepalo"]<6)
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149     True
# Name: Largo Sepalo, Length: 150, dtype: bool

# %%
df
[
    (df["Largo Sepalo"]>5) &
    (df["Largo Sepalo"]<6)
]
# Out:
# [0       True
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  145    False
#  146    False
#  147    False
#  148    False
#  149     True
#  Name: Largo Sepalo, Length: 150, dtype: bool]

# %%
## Ejercicio
ANCHO del sepalo = 3.5
# y ademas, que el dataframe solo muestre las columnas largo del petalo y clase

# %% [markdown]
# ## Ejercicio
# Filtrar ANCHO del sepalo = 3.5 y ademas, que el dataframe solo muestre las columnas largo del petalo y clase

# %%
df[df["Ancho Sepalo"]==3.5]
# Out:
#     Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo        Clase  \
# 0            5.1           3.5           1.4           0.2  Iris-setosa
# 17           5.1           3.5           1.4           0.3  Iris-setosa
# 27           5.2           3.5           1.5           0.2  Iris-setosa
# 36           5.5           3.5           1.3           0.2  Iris-setosa
# 40           5.0           3.5           1.3           0.3  Iris-setosa
# 43           5.0           3.5           1.6           0.6  Iris-setosa
#
#     suma acumulada LS  KPI 27
# 0                 5.1   24.61
# 17               89.9   24.61
# 27              140.9   25.54
# 36              187.1   28.95
# 40              206.5   23.70
# 43              220.4   23.40

# %%
vista1 = ["Largo Petalo","Clase"]
df[df["Ancho Sepalo"]==3.5][vista1]
# Out:
#     Largo Petalo        Clase
# 0            1.4  Iris-setosa
# 17           1.4  Iris-setosa
# 27           1.5  Iris-setosa
# 36           1.3  Iris-setosa
# 40           1.3  Iris-setosa
# 43           1.6  Iris-setosa

# %%
df[df["Ancho Sepalo"]==3.5][["Largo Petalo","Clase"]]
# Out:
#     Largo Petalo        Clase
# 0            1.4  Iris-setosa
# 17           1.4  Iris-setosa
# 27           1.5  Iris-setosa
# 36           1.3  Iris-setosa
# 40           1.3  Iris-setosa
# 43           1.6  Iris-setosa

# %% [markdown]
# ## Ejercicio 2. Calcular el promedio de "Largo Sepalo" para la clase Iris-Setosa.

# %%
df[df.Clase=="Iris-setosa"]["Largo Sepalo"].mean()
# Out:
# 5.006

# %%
df[df.Clase=="Iris-versicolor"]["Largo Sepalo"].mean()
# Out:
# 5.936

# %%
df[df.Clase=="Iris-virginica"]["Largo Sepalo"].mean()
# Out:
# 6.587999999999998

# %%
df.Clase.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
for i in df.Clase.unique():
  print(df[df.Clase==i]["Largo Sepalo"].mean())
# Out:
# 5.006
# 5.936
# 6.587999999999998

# %% [markdown]
# # iloc, loc (seleccionamos filas y columnas, y podemos modificarlas)

# %%
df2=df.copy()
df2
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase  \
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
#      suma acumulada LS  KPI 27
# ...

# %%
df2.iloc[1,1]
# Out:
# 3.0

# %%
df2.iloc[1,1] = 100
df2
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase  \
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9         100.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
#      suma acumulada LS  KPI 27
# ...

# %%
df2.iloc[2:4, 1:4] = 200
df2
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase  \
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9         100.0           1.4           0.2     Iris-setosa
# 2             4.7         200.0         200.0         200.0     Iris-setosa
# 3             4.6         200.0         200.0         200.0     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
#      suma acumulada LS  KPI 27
# ...

# %%
df2.iloc[50:61, 2:4]
df2.head()
# Out:
#    Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo        Clase  \
# 0           5.1           3.5           1.4           0.2  Iris-setosa
# 1           4.9         100.0           1.4           0.2  Iris-setosa
# 2           4.7         200.0         200.0         200.0  Iris-setosa
# 3           4.6         200.0         200.0         200.0  Iris-setosa
# 4           5.0           3.6           1.4           0.2  Iris-setosa
#
#    suma acumulada LS  KPI 27
# 0                5.1   24.61
# 1               10.0   22.61
# 2               14.7   20.79
# 3               19.3   19.66
# 4               24.3   23.60

# %% [markdown]
# #LOC

# %%
df2.index = ["indice"+str(i) for i in range (150)]
df2
# Out:
#            Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo  \
# indice0             5.1           3.5           1.4           0.2
# indice1             4.9         100.0           1.4           0.2
# indice2             4.7         200.0         200.0         200.0
# indice3             4.6         200.0         200.0         200.0
# indice4             5.0           3.6           1.4           0.2
# ...                 ...           ...           ...           ...
# indice145           6.7           3.0           5.2           2.3
# indice146           6.3           2.5           5.0           1.9
# indice147           6.5           3.0           5.2           2.0
# indice148           6.2           3.4           5.4           2.3
# indice149           5.9           3.0           5.1           1.8
#
#                     Clase  suma acumulada LS  KPI 27
# indice0       Iris-setosa                5.1   24.61
# indice1       Iris-setosa               10.0   22.61
# ...

# %%
df2.loc["indice2","Largo Sepalo"]
# Out:
# 4.7

# %%
df2.loc["indice2",["Largo Sepalo","Ancho Sepalo"]]=99
df2
# Out:
#            Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo  \
# indice0             5.1           3.5           1.4           0.2
# indice1             4.9         100.0           1.4           0.2
# indice2            99.0          99.0         200.0         200.0
# indice3             4.6         200.0         200.0         200.0
# indice4             5.0           3.6           1.4           0.2
# ...                 ...           ...           ...           ...
# indice145           6.7           3.0           5.2           2.3
# indice146           6.3           2.5           5.0           1.9
# indice147           6.5           3.0           5.2           2.0
# indice148           6.2           3.4           5.4           2.3
# indice149           5.9           3.0           5.1           1.8
#
#                     Clase  suma acumulada LS  KPI 27
# indice0       Iris-setosa                5.1   24.61
# indice1       Iris-setosa               10.0   22.61
# ...

# %%
df2.loc[df2["Largo Sepalo"]>=5, "Largo Sepalo"] = 5.5
df2
# Out:
#            Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo  \
# indice0             5.5           3.5           1.4           0.2
# indice1             4.9         100.0           1.4           0.2
# indice2             5.5          99.0         200.0         200.0
# indice3             4.6         200.0         200.0         200.0
# indice4             5.5           3.6           1.4           0.2
# ...                 ...           ...           ...           ...
# indice145           5.5           3.0           5.2           2.3
# indice146           5.5           2.5           5.0           1.9
# indice147           5.5           3.0           5.2           2.0
# indice148           5.5           3.4           5.4           2.3
# indice149           5.5           3.0           5.1           1.8
#
#                     Clase  suma acumulada LS  KPI 27
# indice0       Iris-setosa                5.1   24.61
# indice1       Iris-setosa               10.0   22.61
# ...

# %%
df2.loc[df2["Largo Sepalo"]>=5, "Largo Sepalo"] = "hoy es lunes"
df2
# Out:
#            Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo  \
# indice0    hoy es lunes           3.5           1.4           0.2
# indice1             4.9         100.0           1.4           0.2
# indice2    hoy es lunes          99.0         200.0         200.0
# indice3             4.6         200.0         200.0         200.0
# indice4    hoy es lunes           3.6           1.4           0.2
# ...                 ...           ...           ...           ...
# indice145  hoy es lunes           3.0           5.2           2.3
# indice146  hoy es lunes           2.5           5.0           1.9
# indice147  hoy es lunes           3.0           5.2           2.0
# indice148  hoy es lunes           3.4           5.4           2.3
# indice149  hoy es lunes           3.0           5.1           1.8
#
#                     Clase  suma acumulada LS  KPI 27
# indice0       Iris-setosa                5.1   24.61
# indice1       Iris-setosa               10.0   22.61
# ...

# %% [markdown]
# #Cambiar nombres columnas

# %%
df = iris.copy()
df
# Out:
#      Largo Sepalo   Ancho Sepalo   Largo Petalo   Ancho Petalo           Clase
# 0             5.1            3.5            1.4            0.2     Iris-setosa
# 1             4.9            3.0            1.4            0.2     Iris-setosa
# 2             4.7            3.2            1.3            0.2     Iris-setosa
# 3             4.6            3.1            1.5            0.2     Iris-setosa
# 4             5.0            3.6            1.4            0.2     Iris-setosa
# ..            ...            ...            ...            ...             ...
# 145           6.7            3.0            5.2            2.3  Iris-virginica
# 146           6.3            2.5            5.0            1.9  Iris-virginica
# 147           6.5            3.0            5.2            2.0  Iris-virginica
# 148           6.2            3.4            5.4            2.3  Iris-virginica
# 149           5.9            3.0            5.1            1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['Largo Sepalo', ' Ancho Sepalo', ' Largo Petalo', ' Ancho Petalo',
#        ' Clase'],
#       dtype='object')

# %%
df.columns = ["a", "b", "c", "d", "e"]
df.head(5)
# Out:
#      a    b    c    d            e
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
df.rename(columns={"e":"A", "a":"B"})
# Out:
#        B    b    c    d               A
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.rename(columns={"a":"A1", "b":"B1"}, inplace=True)
df.head()
# Out:
#     A1   B1    c    d            e
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
df = df.sort_values("c", ascending=False)

# %%
df
# Out:
#       A1   B1    c    d               e
# 118  7.7  2.6  6.9  2.3  Iris-virginica
# 122  7.7  2.8  6.7  2.0  Iris-virginica
# 117  7.7  3.8  6.7  2.2  Iris-virginica
# 105  7.6  3.0  6.6  2.1  Iris-virginica
# 131  7.9  3.8  6.4  2.0  Iris-virginica
# ..   ...  ...  ...  ...             ...
# 36   5.5  3.5  1.3  0.2     Iris-setosa
# 35   5.0  3.2  1.2  0.2     Iris-setosa
# 14   5.8  4.0  1.2  0.2     Iris-setosa
# 13   4.3  3.0  1.1  0.1     Iris-setosa
# 22   4.6  3.6  1.0  0.2     Iris-setosa
#
# [150 rows x 5 columns]

# %% [markdown]
# #Resetear el índice

# %%
df2 = df.reset_index(drop=False)
df2
# Out:
#      index   A1   B1    c    d               e
# 0      118  7.7  2.6  6.9  2.3  Iris-virginica
# 1      122  7.7  2.8  6.7  2.0  Iris-virginica
# 2      117  7.7  3.8  6.7  2.2  Iris-virginica
# 3      105  7.6  3.0  6.6  2.1  Iris-virginica
# 4      131  7.9  3.8  6.4  2.0  Iris-virginica
# ..     ...  ...  ...  ...  ...             ...
# 145     36  5.5  3.5  1.3  0.2     Iris-setosa
# 146     35  5.0  3.2  1.2  0.2     Iris-setosa
# 147     14  5.8  4.0  1.2  0.2     Iris-setosa
# 148     13  4.3  3.0  1.1  0.1     Iris-setosa
# 149     22  4.6  3.6  1.0  0.2     Iris-setosa
#
# [150 rows x 6 columns]

# %% [markdown]
# # Eliminar filas/columnas (drop)

# %%
df2.drop([2,5,1], axis = 0)
df2.head()
# Out:
#    index   A1   B1    c    d               e
# 0    118  7.7  2.6  6.9  2.3  Iris-virginica
# 1    122  7.7  2.8  6.7  2.0  Iris-virginica
# 2    117  7.7  3.8  6.7  2.2  Iris-virginica
# 3    105  7.6  3.0  6.6  2.1  Iris-virginica
# 4    131  7.9  3.8  6.4  2.0  Iris-virginica

# %%
df.drop(columns=["B1", "d"])
# Out:
#       A1    c               e
# 118  7.7  6.9  Iris-virginica
# 122  7.7  6.7  Iris-virginica
# 117  7.7  6.7  Iris-virginica
# 105  7.6  6.6  Iris-virginica
# 131  7.9  6.4  Iris-virginica
# ..   ...  ...             ...
# 36   5.5  1.3     Iris-setosa
# 35   5.0  1.2     Iris-setosa
# 14   5.8  1.2     Iris-setosa
# 13   4.3  1.1     Iris-setosa
# 22   4.6  1.0     Iris-setosa
#
# [150 rows x 3 columns]
