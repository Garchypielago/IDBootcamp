# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font size="3"><a href='https://www.linkedin.com/in/adrianceja/'> <span style="color: #5E62D1;"> <strong> Adrián Y. Ceja Flores</strong></span></a></font>
#
# <font size="3"><a href='https://www.instagram.com/p/CKzW3I1sOkV/'><span style="color: #5E62D1;"><strong>Alfonso D. Blázquez</strong></span></a></font>

# %% [markdown]
# <font size="7"><span style="color: #33D6CC;">Ejercicios del condicional **if** </span></font>

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 1.De acuerdo con el valor de la siguiente variable, imprime si es positiva o negativa.</span></font>

# %%
x = -45

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 2. Crea un código que imprima de acuerdo con la comunidad autonoma donde vive una persona su gentilicio. Por ejemplo: Galicia: "Gallego"</span></font>

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 3. Pide al usuario que ingrese un número utilizando la función input(). Después imprime si el número es par o impar.</span></font>

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 4. Pide al usuario que ingrese un número y comprueba si es múltiplo de 3.</span></font>

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 5. Pide al usuario que ingrese un año entre 1900 y 2050 y comprueba si es bisiesto.</span></font>

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 6. De acuerdo con la siguiente imagen, donde se muestran las características de un Teckel o Dachshund, crea un código utilizando condicionales IF para identificar si un perro es Teckel o no.</span></font>

# %% [markdown]
# ![image.png](attachment:72400800-7da5-4a2b-9079-5878cfee8d92.png)

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 7. Utiliza un bucle **FOR** para recorrer la siguiente lista, mientras se crea una lista con la palabra "positivo" o "negativo" dependiendo del número que se esta evaluando al recorrer la lista. La lista con las palabras "positivo" y "negativo" debes llamarla lista2.</span></font>

# %%
lista = [-1, -2, -4, -5, 1, 5, 9, 3, -2, 4, 3, 0]
lista
# Out:
# [-1, -2, -4, -5, 1, 5, 9, 3, -2, 4, 3, 0]

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 8. Utiliza la lista2 del ejercicio anterior para recorrerla con un bucle **FOR** y en dos variables guarda el número de apariciones de cada palabra (positivo y negativo).</span></font>

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 9. En la siguiente imagen se puede ver de acuerdo con el IMC cual es el rango de la persona. Pide al usuario que ingrese su altura y peso e imprime el IMC de la persona y el rango que le corresponde </span></font>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 10. Pide al usuario que ingrese su valor de Albuminuria, el cual debe de estar en un rango entre 0 y 500 y que ingrese el valor de su GFR. El cual debe de estar entre 0 y 300. De acuerdo con esta información imprime el color que se le asigna a esa persona. Entre los colores verde, amarillo, naranja y rojo. </span></font>

# %% [markdown]
# ![image.png](attachment:image.png)
