# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# <font size="3"><a href='https://www.linkedin.com/in/adrianceja/'> <span style="color: #5E62D1;"> <strong> Adrián Y. Ceja Flores</strong></span></a></font>
#
# <font size="3"><a href='https://www.instagram.com/p/CKzW3I1sOkV/'><span style="color: #5E62D1;"><strong>Alfonso D. Blázquez</strong></span></a></font>

# %% [markdown]
# <font size="7"><span style="color: #33D6CC;">Ejercicios de sets</span></font>

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 1. Crea un diccionario con 5 items, preguntando al usuario nombre y edad y donde las edades serán los valores. Nota: utiliza la función input() para pedir valores al usuario.</span></font>

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 2. Crea un diccionario a partir de las siguientes listas.</span></font>

# %%
lista_claves = ['Audi', 'Mercedes', 'BMW']
lista_valores = [442, 542, 124]

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 3. Crea un diccionario a partir de la siguiente lista de claves y cuyos valores serán los cuadrados de las claves. Por ejemplo si la clave es 10, el cuadrado será 100</span></font>

# %%
claves = [4,5,6,10,65]

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 4. Crea un diccionario donde las claves son "par e "impar" y los valores una lista con los números pares e impares del número 1 al 100.</span></font>

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 5. Invierte los valores por las claves del siguiente diccionario.</span></font>

# %%
diccionario = {"clave1":"Num1", "clave2":"Num2", "clave3":"Num3"}
diccionario
# Out:
# {'clave1': 'Num1', 'clave2': 'Num2', 'clave3': 'Num3'}

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 6. Aplica la siguiente operación a las claves para generar el valor de cada clave y crea un diccionario.</span></font>

# %% [markdown]
# ### Operacion:
#
# $$y = 1-(x**2)-((3*5)/(0.6+x))$$

# %%
claves = [1,3,5,7,9]

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 7. Crea un diccionario de diccionarios utilizando bucles for, pueden contener las claves y valores que desees.</span></font>

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 8. De acuerdo con los dos diccionarios presentados a continuación, crea un tercer diccionario con las mismas claves donde el valor sea la suma de los valores de los diccionarios presentados.</span></font>

# %%
dic1 = {"a":4, "b":10, "c":40}
dic2 = {"a":30, "b":4, "c":-4}

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 9. Pide al usuario que ingrese una frase y crea un diccionario donde las claves son las palabras de la frase y los valores el índice de la palabra en la frase.</span></font>

# %% [markdown]
# <font size="3"><span style="color: #5E62D1;"> 10. Pide al usuario que ingrese una frase y crea un diccionario donde las claves son las palabras de la frase y los valores el número de veces que se repite esa palabra en la frase.</span></font>
